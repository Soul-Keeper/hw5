# %%
# !git clone https://github.com/open-mmlab/mmaction2.git
# Out:
# Cloning into 'mmaction2'...
# remote: Enumerating objects: 21411, done.
# remote: Counting objects: 100% (521/521), done.
# remote: Compressing objects: 100% (376/376), done.
# remote: Total 21411 (delta 245), reused 304 (delta 141), pack-reused 20890
# Receiving objects: 100% (21411/21411), 68.71 MiB | 12.06 MiB/s, done.
# Resolving deltas: 100% (15060/15060), done.

# %%
# %cd mmaction2
# !python -m pip install -e .
# Out:
# /content/mmaction2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/mmaction2
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 107.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 6.3 MB/s eta 0:00:00
# ...
#   Running setup.py develop for mmaction2
# ...

# %%
# %cd ..
# Out:
# /content

# %%
# !python -m pip install -U torch==1.12.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.3/776.3 MB 2.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.0.2+cu118 requires torch==2.0.1, but you have torch 1.12.0 which is incompatible.
# torchdata 0.6.1 requires torch==2.0.1, but you have torch 1.12.0 which is incompatible.
# torchtext 0.15.2 requires torch==2.0.1, but you have torch 1.12.0 which is incompatible.
# torchvision 0.15.2+cu118 requires torch==2.0.1, but you have torch 1.12.0 which is incompatible.
# ...

# %%
# !python -m pip cache purge
# Out:
# Files removed: 6

# %%
# !pip install -U openmim
# !mim install mmcv mmcv-full
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 kB 5.0 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu102/torch1.12.0/index.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 MB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 25.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.3/374.3 kB 25.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.3/250.3 kB 31.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 3.3.0
#     Uninstalling platformdirs-3.3.0:
#       Successfully uninstalled platformdirs-3.3.0
# ...

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1i7TqXRuaazFQxOCXtUhmQCu02iIovDU-' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1i7TqXRuaazFQxOCXtUhmQCu02iIovDU-" -O dancing.pkl && rm -rf /tmp/cookies.txt
# Out:
# --2023-06-13 17:52:59--  https://docs.google.com/uc?export=download&confirm=t&id=1i7TqXRuaazFQxOCXtUhmQCu02iIovDU-
# Resolving docs.google.com (docs.google.com)... 142.250.4.102, 142.250.4.101, 142.250.4.113, ...
# Connecting to docs.google.com (docs.google.com)|142.250.4.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-04-7o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/r0jfcs71bdicm3qdqltdf4jvg33osb03/1686678750000/05889481493463736502/*/1i7TqXRuaazFQxOCXtUhmQCu02iIovDU-?e=download&uuid=ce3a05f6-a920-4eb3-86fd-823b0219d3e0 [following]
# ...
# --2023-06-13 17:52:59--  https://doc-04-7o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/r0jfcs71bdicm3qdqltdf4jvg33osb03/1686678750000/05889481493463736502/*/1i7TqXRuaazFQxOCXtUhmQCu02iIovDU-?e=download&uuid=ce3a05f6-a920-4eb3-86fd-823b0219d3e0
# ...

# %%
# !python ./mmaction2/tools/test.py posec3d_dancing.py best_acc_top1_epoch_3.pth
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/usr/local/lib/python3.10/dist-packages/torchvision/image.so: undefined symbol: _ZN3c104impl8GPUTrace13gpuTraceStateE'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# 06/13 17:57:43 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 1711380391
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.12.0+cu102
# ...
